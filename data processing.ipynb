# %%
import pandas as pd
url = "https://raw.githubusercontent.com/vkrit/data-science-class/master/WA_Fn-UseC_-Sales-Win-Loss.csv"

# %%
sales_data = pd.read_csv(url)

# %%
sales_data
# Out:
#        Opportunity Number        Supplies Subgroup          Supplies Group  \
# 0                 1641984     Exterior Accessories         Car Accessories
# 1                 1658010     Exterior Accessories         Car Accessories
# 2                 1674737         Motorcycle Parts  Performance & Non-auto
# 3                 1675224            Shelters & RV  Performance & Non-auto
# 4                 1689785     Exterior Accessories         Car Accessories
# ...                   ...                      ...                     ...
# 78020            10089932  Batteries & Accessories         Car Accessories
# 78021            10089961            Shelters & RV  Performance & Non-auto
# 78022            10090145     Exterior Accessories         Car Accessories
# 78023            10090430     Exterior Accessories         Car Accessories
# 78024            10094255     Interior Accessories         Car Accessories
#
#              Region Route To Market  Elapsed Days In Sales Stage  \
# ...

# %%
sales_data.head()
# Out:
#    Opportunity Number     Supplies Subgroup          Supplies Group  \
# 0             1641984  Exterior Accessories         Car Accessories
# 1             1658010  Exterior Accessories         Car Accessories
# 2             1674737      Motorcycle Parts  Performance & Non-auto
# 3             1675224         Shelters & RV  Performance & Non-auto
# 4             1689785  Exterior Accessories         Car Accessories
#
#       Region Route To Market  Elapsed Days In Sales Stage Opportunity Result  \
# 0  Northwest    Fields Sales                           76                Won
# 1    Pacific        Reseller                           63               Loss
# 2    Pacific        Reseller                           24                Won
# 3    Midwest        Reseller                           16               Loss
# 4    Pacific        Reseller                           69               Loss
#
#    Sales Stage Change Count  Total Days Identified Through Closing  \
# ...

# %%
sales_data.head(n=2)
# Out:
#    Opportunity Number     Supplies Subgroup   Supplies Group     Region  \
# 0             1641984  Exterior Accessories  Car Accessories  Northwest
# 1             1658010  Exterior Accessories  Car Accessories    Pacific
#
#   Route To Market  Elapsed Days In Sales Stage Opportunity Result  \
# 0    Fields Sales                           76                Won
# 1        Reseller                           63               Loss
#
#    Sales Stage Change Count  Total Days Identified Through Closing  \
# 0                        13                                    104
# 1                         2                                    163
#
#    Total Days Identified Through Qualified  Opportunity Amount USD  \
# 0                                      101                       0
# 1                                      163                       0
#
#    Client Size By Revenue  Client Size By Employee Count  \
# 0                       5                              5
# ...

# %%
sales_data.tail()
# Out:
#        Opportunity Number        Supplies Subgroup          Supplies Group  \
# 78020            10089932  Batteries & Accessories         Car Accessories
# 78021            10089961            Shelters & RV  Performance & Non-auto
# 78022            10090145     Exterior Accessories         Car Accessories
# 78023            10090430     Exterior Accessories         Car Accessories
# 78024            10094255     Interior Accessories         Car Accessories
#
#              Region Route To Market  Elapsed Days In Sales Stage  \
# 78020     Southeast        Reseller                            0
# 78021     Northeast        Reseller                            0
# 78022     Southeast        Reseller                            0
# 78023     Southeast    Fields Sales                            0
# 78024  Mid-Atlantic        Reseller                            0
#
#       Opportunity Result  Sales Stage Change Count  \
# 78020               Loss                         2
# ...

# %%
sales_data.dtypes
# Out:
# Opportunity Number                           int64
# Supplies Subgroup                           object
# Supplies Group                              object
# Region                                      object
# Route To Market                             object
# Elapsed Days In Sales Stage                  int64
# Opportunity Result                          object
# Sales Stage Change Count                     int64
# Total Days Identified Through Closing        int64
# Total Days Identified Through Qualified      int64
# Opportunity Amount USD                       int64
# Client Size By Revenue                       int64
# Client Size By Employee Count                int64
# Revenue From Client Past Two Years           int64
# Competitor Type                             object
# Ratio Days Identified To Total Days        float64
# Ratio Days Validated To Total Days         float64
# Ratio Days Qualified To Total Days         float64
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="whitegrid", color_codes=True)
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.countplot('Region', data=sales_data,hue='Opportunity Result')
sns.despine(offset=10, trim=True)

# %%
sns.violinplot(x="Opportunity Result",y="Revenue From Client Past Two Years", hue="Opportunity Result", data=sales_data);

# %% [markdown]
# # Preprocessing

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
encoded_value = label_encoder.fit_transform(["paris", "paris", "tokyo", "amsterdam"])
print(encoded_value)
# Out:
# [1 1 2 0]

# %%
print("Supplies Subgroup' : ", sales_data['Supplies Subgroup'].unique())
# Out:
# Supplies Subgroup' :  ['Exterior Accessories' 'Motorcycle Parts' 'Shelters & RV'
#  'Garage & Car Care' 'Batteries & Accessories' 'Performance Parts'
#  'Towing & Hitches' 'Replacement Parts' 'Tires & Wheels'
#  'Interior Accessories' 'Car Electronics']

# %%
print("Region : ",sales_data['Region'])
# Out:
# Region :  0           Northwest
# 1             Pacific
# 2             Pacific
# 3             Midwest
# 4             Pacific
#              ...
# 78020       Southeast
# 78021       Northeast
# 78022       Southeast
# 78023       Southeast
# 78024    Mid-Atlantic
# Name: Region, Length: 78025, dtype: object

# %%
from sklearn import preprocessing
labelEncoder = preprocessing.LabelEncoder()
sales_data['Supplies Subgroup'] = labelEncoder.fit_transform(sales_data['Supplies Subgroup']);
sales_data['Region'] = labelEncoder.fit_transform(sales_data['Region'])
sales_data['Route To Market'] = labelEncoder.fit_transform(sales_data['Route To Market'])
sales_data['Opportunity Result'] = labelEncoder.fit_transform(sales_data['Opportunity Result'])
sales_data['Competitor Type'] = labelEncoder.fit_transform(sales_data['Competitor Type'])
sales_data['Supplies Group'] = labelEncoder.fit_transform(sales_data['Supplies Group'])

# %%
sales_data.head()
# Out:
#    Opportunity Number  Supplies Subgroup  Supplies Group  Region  \
# 0             1641984                  2               0       3
# 1             1658010                  2               0       4
# 2             1674737                  5               2       4
# 3             1675224                  8               2       1
# 4             1689785                  2               0       4
#
#    Route To Market  Elapsed Days In Sales Stage  Opportunity Result  \
# 0                0                           76                   1
# 1                2                           63                   0
# 2                2                           24                   1
# 3                2                           16                   0
# 4                2                           69                   0
#
#    Sales Stage Change Count  Total Days Identified Through Closing  \
# 0                        13                                    104
# ...

# %%
cols = ["Supplies Subgroup", "Supplies Group", "Region", "Route To Market", "Elapsed Days In Sales Stage","Sales Stage Change Count","Total Days Identified Through Closing","Total Days Identified Through Qualified","Opportunity Amount USD","Client Size By Revenue","Client Size By Employee Count","Revenue From Client Past Two Years","Competitor Type","Ratio Days Identified To Total Days","Ratio Days Validated To Total Days","Ratio Days Qualified To Total Days","Deal Size Category"] 
data = sales_data[cols]
target = sales_data['Opportunity Result']

# %%
data.head(n=2)
# Out:
#    Supplies Subgroup  Supplies Group  Region  Route To Market  \
# 0                  2               0       3                0
# 1                  2               0       4                2
#
#    Elapsed Days In Sales Stage  Sales Stage Change Count  \
# 0                           76                        13
# 1                           63                         2
#
#    Total Days Identified Through Closing  \
# 0                                    104
# 1                                    163
#
#    Total Days Identified Through Qualified  Opportunity Amount USD  \
# 0                                      101                       0
# 1                                      163                       0
#
#    Client Size By Revenue  Client Size By Employee Count  \
# 0                       5                              5
# 1                       3                              5
#
#    Revenue From Client Past Two Years  Competitor Type  \
# ...

# %%
target.head(n=2)
# Out:
# 0    1
# 1    0
# Name: Opportunity Result, dtype: int32

# %%
from sklearn.model_selection import train_test_split

# %%
data_train, data_test, target_train, target_test = train_test_split(data,target, test_size = 0.30, random_state = 10)

# %% [markdown]
# # building the model

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score
gnb = GaussianNB()
#training
pred = gnb.fit(data_train, target_train).predict(data_test)
print("Naive-Bayes accuracy: ",accuracy_score(target_test, pred, normalize= True))
# Out:
# Naive-Bayes accuracy:  0.7590567327409433

# %%
from sklearn.svm import LinearSVC
from sklearn.metrics import accuracy_score
svc_model = LinearSVC(random_state=0)
pred = svc_model.fit(data_train, target_train).predict(data_test)
print("LinearSVC accuracy: ",accuracy_score(target_test, pred, normalize = True))
# Out:
# LinearSVC accuracy:  0.777811004784689
# C:\Users\mingj\Anaconda3\lib\site-packages\sklearn\svm\base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
neigh = KNeighborsClassifier(n_neighbors=3)
neigh.fit(data_train, target_train)
pred = neigh.predict(data_test)
print("KNeighbors accuracy score: ",accuracy_score(target_test, pred))
# Out:
# KNeighbors accuracy score:  0.8145505809979494

# %% [markdown]
# # Performance Comparison

# %%
from yellowbrick.classifier import ClassificationReport
# Instantiate the classification model and visualizer
visualizer = ClassificationReport(gnb, classes=['Won3','Loss'])
visualizer.fit(data_train, target_train) # Fit the training data to the visualizer
visualizer.score(data_test, target_test) # Evaluate the model on the test data
g = visualizer.poof() # Draw/show/poof the data

# %%
from yellowbrick.classifier import ClassificationReport
visualizer = ClassificationReport(svc_model, classes=['Won','Loss'])
visualizer.fit(data_train, target_train)
visualizer.score(data_test, target_test)
g = visualizer.poof()

# %%
print(g)
# Out:
# AxesSubplot(0.0579713,0.107873;0.741315x0.84677)

# %%
from yellowbrick.classifier import ClassificationReport
# Instantiate the classification model and visualizer
visualizer = ClassificationReport(neigh, classes=['Won','Loss'])
visualizer.fit(data_train, target_train) # Fit the training data to the visualizer
visualizer.score(data_test, target_test) # Evaluate the model on the test data
g = visualizer.poof() # Draw/show/poof the data
